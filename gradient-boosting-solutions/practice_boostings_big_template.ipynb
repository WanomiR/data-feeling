# %% [markdown]
# # Большой практический урок.

# %% [markdown]
# В этом уроке предлагаем вам упорядочить и систематизировать полученный опыт из предыдущих разделов и оформить ноутбук, который будут проверять такие же студенты как вы.
#
# Задача с рецензированием, чтобы получить итоговый балл необходимо чтобы вашу работу проверили 3 человека (для объективной оценки), поэтому не поленитесь проверить несколько работ ваших коллег. Если рецензентов будет не хватать, то будет проверка от преподавателей курса. При проверке других работ желательно оставлять поясняющие комментарии, особенно, при снижении баллов (помни заповедь: проверяй других так, как хочешь, чтобы проверяли тебя!).
#
# Постарайтесь подойти к заданию творчески и основательно - возможно, это будет ваш начальный шаблон для дальнейших соревнований, но расписывать огромные простыни на сотню ячеек тоже не стоит.

# %% [markdown]
# ## Задача

# %% [markdown]
# **"Обучи несколько бустингов на 3-х фолдах, выбери лучшие, усредни предсказания"**
# Если вы думает, что это задание - больная фантазия авторов, то нет - это, как раз, реальные кейсы с соревнований. Можно назвать это задание подготовкой к модулю про блендинг и стэккинг.
#
# Датасеты: [quickstart_train.csv ](https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/quickstart_train.csv)и [quickstart_test.csv](https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/quickstart_test.csv)
#
# Регрессионный таргет: столбец `target_reg` , метрика `RMSE`
#
# **Модели**, которые необходимо обучить:
#
# - `CatBoostRegressor`
# - `LightGBMRegressor` (goss)
# - `XGBoostRegressor` (dart)
#
# **Бонусом**, для тех кому покажется мало, можно обучить ещё 3 модели (не влияет на итоговый балл):
#
# - `CatBoostRegressor` с другим `random_seed`
# - `LightGBMRegressor` (dart)
# - `XGBoostRegressor` (gbtree)
#
# В этом случае усредняем лучшие фолды от 6 моделей.
#
# **Дополнительные условия**:
#
# - Все модели обучаем на 3-х фолдах
# - Выбираем лучший фолд от каждой модели (получаем 6 лучших моделей)
# - Обязательно должна быть добавлена ячейка с сохранением 6 лучших моделей
# - Делаем итоговое предсказание на тестовом датасете, усреднив предсказание от 6 лучших моделей
# - Сохраняем в `submission.csv` только колонки `car_id` и `target_reg`
# - В конце добавляем небольшой текстовый блок с выводами
# - Желательно, чтобы на выполнение всего ноутбука уходило не более 30 мин.
# - Не добавляем новые признаки
# - Не используем GPU
# - Не используем Optuna
#
# Что можно использовать (но не обязательно)?
# - `Feature Selection`
# - `Object importance`
# - Подбор гиперпараметров
# - Графику
# - Колбэки, шедулеры, кастомы
#
# Формат сдачи:
#
# - В текстовом поле вводим ссылки на онлайн версию jupyter ноутбука (GoogleСolab, Kaggle) с выполненным заданием, и публичную ссылку на файлхостинг (GoogleDrive, ЯндексДиск или др.) с оригиналом ноутбука. (проверяем, что они работают).
# - Во вложение добавляем тот же ноутбук, сохраненный в формате pdf с аутпутами всех ячеек (не более 5 Mb).
# - В следующем шаге отправляем получившийся CSV файл с предсказаниями. Можно использовать его, как аналог лидерборда, чтобы узнавать скор предсказаний.
#
#
# **Критерии оценки (максимум 10 баллов за задание):**
#
# **Оформление (3 балла)**
# - прослеживается логика в последовательности решения задачи; в неочевидных местах добалены поясняющие комментарии и маркдаун ячейки. ноутбук не пергружен лишней информацией, огромными простынями аутпутов ячеек (настраиваем verbose, скрываем служебную информацию после установки библиотек)
# - хороший codestyle: код соответствует [PEP 8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html) и [DRY](https://realpython.com/lessons/dry-principle/), названия переменных и функций понятны, либо соответствуют общепринятым нормам (train, test, model, pd, xgb и.т.п.)
# - в конце присутствуют выводы о проделанной работе
#
# **Решение задачи и выполнение доп. условий (3 балла)**
# - ноутбук выполняется до конца без ошибок (присутствуют все аутпуты в пдф)
# - обучены все необходимые модели и выполнены доп. условия
# - проведена работа над воспроизводимостью (зафиксированы все random seeds)
# - присутствуют и отрабатывают ячейки для сохранения лучших моделей и итогового файла с предсказанием
#
#  **Использование возможностей фрэймворка (2 балла)**
# - датсеты загружаются с помощью соответствующих классов (Pool, Dmatrix, Dataset)
# - используется early_stopping, многопоточность (n_threads) и пр.
# - правильная подготовка категориальных признаков для каждой модели.
#
#  **Дополнительные баллы (макс. 2 балла)**
# - 1 балл, если проводился подбор гиперпараметров;
# - 1 балл, если использованы минимум 2 вида графики и на основе её сделаны какие-либо выводы (не просто график ради картинки красивой, а с пользой для дела);
# - 1 балл, если проводился feature selection или object selection
# - 1 балл, если использовались scheduler или custom callbacks

# %% [markdown]
# ## Установка сторонник библиотек

# %%
# !pip install catboost -q
# !pip install shap -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 10.1 MB/s eta 0:00:00

# %% [markdown]
# ## Импорт библиотек

# %%
import time
import warnings
from math import sqrt

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import shap
import xgboost as xgb
from catboost import CatBoostRegressor, Pool
from lightgbm import Dataset
from matplotlib.cm import get_cmap
from matplotlib.pyplot import cm
from scipy import stats
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgbm

shap.initjs()

matplotlib.style.use("ggplot")
pd.set_option("display.max_rows", None)
pd.options.mode.chained_assignment = None

warnings.filterwarnings(action="ignore", message="Mean of empty slice")
warnings.filterwarnings("ignore")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# ## Вспомогательные функции

# %%
def plot_numerical_feature_histogram(df1, df2, feature_title, label=None, text_info=True, bins=50,
                                     figure_width=17, figure_height=7, fontsize=15, number_of_decimals=2, title=''):
    NCOLS_NUMBER_CONST = 1

    if label is None:
        label = feature_title

    fig, ax = plt.subplots(ncols=1, figsize=(figure_width, figure_height))

    sns.histplot(data=df1, x=feature_title, color="cornflowerblue", label=label, bins=bins, kde=True)
    mean_value = df1[feature_title].mean()
    median_value = df1[feature_title].median()
    ax.axvline(x=mean_value, color='black', lw=2, ls=':',
               label=f"mean: {round(mean_value, number_of_decimals)}")
    ax.axvline(x=median_value, color='orange', lw=2, ls='-.',
               label=f"median: {round(median_value, number_of_decimals)}")
    ax.legend(fontsize='15', title_fontsize="10", loc='upper right')
    plt.tight_layout()

    Q1_QUANTILE_VALUE_CONST = float(0.25)
    Q3_QUANTILE_VALUE_CONST = float(0.75)
    IQR_MULT_DEFAULT_CONST = float(1.5)
    Q1 = df1[feature_title].quantile(Q1_QUANTILE_VALUE_CONST)
    Q3 = df1[feature_title].quantile(Q3_QUANTILE_VALUE_CONST)
    IQR = Q3 - Q1

    sns.histplot(data=df2, x=feature_title, color="orange", label=label, bins=bins, kde=True)
    mean_value = df2[feature_title].mean()
    median_value = df2[feature_title].median()
    ax.axvline(x=mean_value, color='green', lw=2, ls=':',
               label=f"mean: {round(mean_value, number_of_decimals)}")
    ax.axvline(x=median_value, color='red', lw=2, ls='-.',
               label=f"median: {round(median_value, number_of_decimals)}")
    ax.legend(fontsize='15', title_fontsize="10", loc='upper right')
    plt.tight_layout()

    Q1_QUANTILE_VALUE_CONST = float(0.25)
    Q3_QUANTILE_VALUE_CONST = float(0.75)
    IQR_MULT_DEFAULT_CONST = float(1.5)
    Q1 = df2[feature_title].quantile(Q1_QUANTILE_VALUE_CONST)
    Q3 = df2[feature_title].quantile(Q3_QUANTILE_VALUE_CONST)
    IQR = Q3 - Q1

    plt.show()

# %%
def plot_dataframes_features_info(df1, df2, name):
    print('\n', name, '\n')
    for column in df1.describe().columns:
        plot_numerical_feature_histogram(df1, df2, column, figure_width=10, figure_height=5)

# %%
def root_mean_squared_error(target, pred):
    return np.sqrt(mean_squared_error(target, pred))

# %%
rmse_scorer = make_scorer(root_mean_squared_error, greater_is_better=False)

# %%
def perform_grid_search(X, y, model, param_grid, rmse_scorer, kf):
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        start = time.time()
        print('\nSearching for the best parameters...')

        grid_search = GridSearchCV(model, param_grid, scoring=rmse_scorer, n_jobs=-1)
        grid_search_result = grid_search.fit(X_train, y_train)

        elapsed_time = time.time() - start
        print(f'Time taken for grid search: {round(elapsed_time / 60, 2)} minutes')
        print('Best parameters:   ', grid_search_result.best_params_)
        print('Best RMSE score: ', round(np.abs(grid_search_result.best_score_), 2))

# %% [markdown]
# ## Загрузка данных

# %%
train = pd.read_csv("https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/quickstart_train.csv")
train.sample(5)
# Out:
#           car_id            model  car_type fuel_type  car_rating  \
# 50    C15164392z      Skoda Rapid   economy    petrol        3.34
# 23    Z-1196295K     Smart ForTwo   economy    petrol        4.54
# 515   z86911952C   Nissan Qashqai  standart    petrol        2.72
# 585   b-3993593n  Hyundai Solaris   economy    petrol        3.62
# 1918  d-1056916g     Kia Sportage  standart    petrol        4.54
#
#       year_to_start  riders  year_to_work  target_reg     target_class  \
# 50             2016   93681          2014       30.45      electro_bug
# 23             2016  115037          2019       24.06  engine_overheat
# 515            2013   37481          2021       33.97      electro_bug
# 585            2013   44987          2022       40.39      engine_fuel
# 1918           2015   81099          2017       32.91        break_bug
#
#       mean_rating  distance_sum  rating_min   speed_max  \
# 50       4.655460  1.330611e+07         0.0  188.978398
# ...

# %%
test = pd.read_csv("https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/quickstart_test.csv")
test.sample(5)
# Out:
#           car_id             model car_type fuel_type  car_rating  \
# 1133  I-2222955D        VW Polo VI  economy    petrol        4.74
# 1238  i97387429H         VW Tiguan  economy    petrol        4.46
# 688   n-4605215n  Volkswagen ID.4   premium   electro        5.06
# 643   Q18803510e        VW Polo VI  economy    petrol        3.70
# 1617  a-2129214S        VW Polo VI  economy    petrol        6.46
#
#       year_to_start  riders  year_to_work     target_class  mean_rating  \
# 1133           2014   58744          2019     engine_check     4.668736
# 1238           2016  103283          2020     engine_check     3.939885
# 688            2017  106498          2018        break_bug     3.883908
# 643            2011    4202          2014  engine_overheat     4.155747
# 1617           2015   86354          2016        break_bug     4.091149
#
#       distance_sum  rating_min   speed_max  user_ride_quality_median  \
# ...

# %%
cat_features = ["car_type", "fuel_type", "model"]
drop_cols = ["car_id", "target_reg", "target_class"]

X = train.drop(drop_cols, axis=1, errors="ignore")
y = train["target_reg"]

for col in cat_features:
    X[col] = X[col].astype('category')

random_state = 830424
random_state_2 = 12346
n_splits = 3

kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

X_train_folds, X_test_folds, y_train_folds, y_test_folds = [], [], [], []

for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    X_train_folds.append(X_train)
    X_test_folds.append(X_test)
    y_train_folds.append(y_train)
    y_test_folds.append(y_test)

# %% [markdown]
# ## Графики

# %% [markdown]
# **Регрессионный таргет**: столбец `target_reg` с метрикой RMSE (Root Mean Squared Error).
#
# Давайте изучим обучающую и тестовую выборки на графике.

# %%
plot_dataframes_features_info(X, test, 'train VS test')
# Out:
#  train VS test

# %% [markdown]
# Выборки в целом очень похожи: распределения признаков практически совпадают.
#
# **Дальнейшие шаги:**
#
# 1. Создадим модели `CatBoostRegressor`, `LGBMRegressor`, `XGBRegressor`.
# 2. Подберем гиперпараметры для каждой модели.
# 3. Обучим модели на 3 фолдах.
# 4. Исследуем важность обучающих признаков и попробуем исключить неважные. Это возможно повысит точность наших моделей.
# 5. Сделаем прогноз на основе 6 лучших моделей и усредним результат.

# %% [markdown]
# ## CatBoost

# %%
for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    train_dataset = Pool(data=X_train, label=y_train, cat_features=cat_features)

    model = CatBoostRegressor(random_state=random_state,
                              cat_features=cat_features,
                              loss_function='RMSE',
                              eval_metric="RMSE",
                              verbose=False,
                              thread_count=-1,
                              early_stopping_rounds=50)

    param_grid = {'depth': [2, 4, 6],
                  'learning_rate': [0.25, 0.05, 0.01],
                  'l2_leaf_reg': [0, 1, 2, 5],
                  'bootstrap_type': ['No', 'Bayesian', 'Bernoulli', 'Poisson']}

    start = time.time()
    print('\nSearching for the best parameters for CatBoostRegressor...')

    randomized_search_result = model.randomized_search(param_grid,
                                                       X=train_dataset,
                                                       y=None,
                                                       partition_random_seed=random_state,
                                                       shuffle=False,
                                                       verbose=False,
                                                       plot=False)

    elapsed_time = time.time() - start
    print(f'Time taken for parameter search: {round(elapsed_time / 60, 2)} minutes')
    print('Best parameters:   ', randomized_search_result['params'])
    print('Best RMSE score: ', model.best_score_)
# Out:
# Searching for the best parameters for CatBoostRegressor...
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.26898854
# bestIteration = 33
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 10.94818474
# bestIteration = 891
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 10.90656842
# bestIteration = 238
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.00548232
# bestIteration = 934
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.12920547
# bestIteration = 125
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.09470693
# bestIteration = 27
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 10.9282193
# bestIteration = 190
#
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 10.79508239
# bestIteration = 349
#
# Training on fold [0/3]
#
# bestTest = 12.35624842
# bestIteration = 197
#
# ...

# %% [markdown]
# ### random_state №1

# %%
classifiers_rs1 = []
scores_classifiers_rs1 = []
indices_classifiers_rs1 = []
indices_scores_classifiers_rs1 = []

for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    train_dataset = Pool(data=X_train, label=y_train, cat_features=cat_features)
    eval_dataset = Pool(data=X_test, label=y_test, cat_features=cat_features)

    clf = CatBoostRegressor(depth=6,
                            iterations=3000,
                            learning_rate=0.05,
                            loss_function='RMSE',
                            eval_metric='RMSE',
                            cat_features=cat_features,
                            l2_leaf_reg=5,
                            bootstrap_type='No',
                            thread_count=-1,
                            random_seed=random_state,
                            early_stopping_rounds=50)

    classifiers_rs1.append(clf)

    clf.fit(train_dataset,
            eval_set=eval_dataset,
            verbose=1000,
            use_best_model=True,
            plot=False)

    scores_classifiers_rs1.append(np.mean([v for k, v in clf.best_score_["validation"].items() if "RMSE" in k], dtype="float16"))

    indices, scores = clf.get_object_importance(eval_dataset, train_dataset,
                                                importance_values_sign="Positive", thread_count=-1)
    indices_classifiers_rs1.append(indices), indices_scores_classifiers_rs1.append(scores)

min_rmse_cb_rs = min(scores_classifiers_rs1)
min_index_cb_rs = scores_classifiers_rs1.index(min_rmse_cb_rs)

assert len(classifiers_rs1) == n_splits
for i in range(len(scores_classifiers_rs1)):
    print(f" Model classifiers_rs1 {i} RMSE score ---------> {scores_classifiers_rs1[i]:.5f}")
# Out:
# 0:	learn: 17.3898421	test: 16.9874608	best: 16.9874608 (0)	total: 4.2ms	remaining: 12.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.49366436
# bestIteration = 191
#
# Shrink model to first 192 iterations.
# 0:	learn: 17.0476211	test: 17.6196441	best: 17.6196441 (0)	total: 3.9ms	remaining: 11.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 12.03672876
# bestIteration = 194
#
# Shrink model to first 195 iterations.
# 0:	learn: 17.2670825	test: 17.2136769	best: 17.2136769 (0)	total: 6.04ms	remaining: 18.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.36403838
# bestIteration = 188
#
# Shrink model to first 189 iterations.
#  Model classifiers_rs1 0 RMSE score ---------> 11.49219
#  Model classifiers_rs1 1 RMSE score ---------> 12.03906
#  Model classifiers_rs1 2 RMSE score ---------> 11.36719

# %%
best_classifier = classifiers_rs1[min_index_cb_rs]
train_data = Pool(data=X_train_folds[min_index_cb_rs],
                  label=y_train_folds[min_index_cb_rs],
                  cat_features=cat_features)

explainer = shap.TreeExplainer(best_classifier)
shap_values = explainer.shap_values(train_data)
shap.summary_plot(shap_values, X_train_folds[min_index_cb_rs], max_display=25)

# %% [markdown]
# **Вывод**: Чем выше максимальное значение скорости, тем больше вероятность получить высокое значение целевой переменной.

# %%
drop_columns_cb_rs = ['deviation_normal_count']
drop_indexes_cb_rs = indices_classifiers_rs1[min_index_cb_rs][:0]

train_data = Pool(
    data=X_train_folds[min_index_cb_rs].drop(index=drop_indexes_cb_rs, errors="ignore").drop(drop_columns_cb_rs, axis=1),
    label=y_train_folds[min_index_cb_rs].drop(index=drop_indexes_cb_rs, errors="ignore"),
    cat_features=cat_features
)
eval_data = Pool(
    data=X_test_folds[min_index_cb_rs].drop(drop_columns_cb_rs, axis=1),
    label=y_test_folds[min_index_cb_rs],
    cat_features=cat_features
)

best_classifier_refit = classifiers_rs1[min_index_cb_rs]
best_classifier_refit.fit(
    train_data,
    eval_set=eval_data,
    verbose=1000,
    use_best_model=True,
    plot=False
)

refit_score = best_classifier_refit.best_score_['validation'].get('RMSE')
print(f"\n Model best_classifier_refit RMSE score ---------> {refit_score:.5f}")
# Out:
# 0:	learn: 17.2670825	test: 17.2136769	best: 17.2136769 (0)	total: 4.35ms	remaining: 13s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.36403838
# bestIteration = 188
#
# Shrink model to first 189 iterations.
#
#  Model best_classifier_refit RMSE score ---------> 11.36404

# %% [markdown]
# ### random_state №2

# %%
classifiers_rs2 = []
scores_classifiers_rs2 = []
indexes_classifiers_rs2 = []
indexes_scores_classifiers_rs2 = []

for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    train_data = Pool(data=X_train, label=y_train, cat_features=cat_features)
    eval_data = Pool(data=X_test, label=y_test, cat_features=cat_features)

    classifier = CatBoostRegressor(
        depth=6,
        iterations=3000,
        learning_rate=0.05,
        loss_function='RMSE',
        eval_metric='RMSE',
        cat_features=cat_features,
        l2_leaf_reg=5,
        bootstrap_type='No',
        thread_count=-1,
        random_seed=random_state_2,
        early_stopping_rounds=50
    )

    classifiers_rs2.append(classifier)

    classifier.fit(
        train_data,
        eval_set=eval_data,
        verbose=1000,
        use_best_model=True,
        plot=False
    )

    scores_classifiers_rs2.append(np.mean(
        [v for k, v in classifier.best_score_["validation"].items() if "RMSE" in k], dtype="float16"))

    indexes, scores = classifier.get_object_importance(
        eval_data, train_data,
        importance_values_sign="Positive", thread_count=-1
    )
    indexes_classifiers_rs2.append(indexes), indexes_scores_classifiers_rs2.append(scores)

min_rmse_cb_rs2 = min(scores_classifiers_rs2)
min_index_cb_rs2 = scores_classifiers_rs2.index(min_rmse_cb_rs2)

assert len(classifiers_rs2) == n_splits
for i in range(len(scores_classifiers_rs2)):
    print(f"Model classifiers_rs2 {i} RMSE score ---------> {scores_classifiers_rs2[i]:.5f}")
# Out:
# 0:	learn: 17.4109535	test: 16.9816359	best: 16.9816359 (0)	total: 3.99ms	remaining: 12s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.40923279
# bestIteration = 224
#
# Shrink model to first 225 iterations.
# 0:	learn: 17.0932337	test: 17.6531332	best: 17.6531332 (0)	total: 4.09ms	remaining: 12.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 12.01176124
# bestIteration = 285
#
# Shrink model to first 286 iterations.
# 0:	learn: 17.3057560	test: 17.2470996	best: 17.2470996 (0)	total: 4.21ms	remaining: 12.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.3212606
# bestIteration = 189
#
# Shrink model to first 190 iterations.
# Model classifiers_rs2 0 RMSE score ---------> 11.40625
# Model classifiers_rs2 1 RMSE score ---------> 12.01562
# Model classifiers_rs2 2 RMSE score ---------> 11.32031

# %%
explainer = shap.TreeExplainer(classifiers_rs2[min_index_cb_rs2])
train_data = Pool(data=X_train_folds[min_index_cb_rs2], label=y_train_folds[min_index_cb_rs2], cat_features=cat_features)
shap_values = explainer.shap_values(train_data)
shap.summary_plot(shap_values, X_train_folds[min_index_cb_rs2], max_display=25)

# %% [markdown]
# **Вывод**: Чем выше максимальное значение скорости, тем больше вероятность получить высокое значение целевой переменной.

# %%
drop_columns_cb_rs2 = ['deviation_normal_count']
drop_indexes_cb_rs2 = indexes_classifiers_rs2[min_index_cb_rs2][:5]

train_data = Pool(
    data=X_train_folds[min_index_cb_rs2].drop(drop_indexes_cb_rs2, errors="ignore").drop(drop_columns_cb_rs2, axis=1),
    label=y_train_folds[min_index_cb_rs2].drop(drop_indexes_cb_rs2, errors="ignore"),
    cat_features=cat_features
)
eval_data = Pool(
    data=X_test_folds[min_index_cb_rs2].drop(drop_columns_cb_rs2, axis=1),
    label=y_test_folds[min_index_cb_rs2],
    cat_features=cat_features
)

best_classifier_refit2 = classifiers_rs2[min_index_cb_rs2]
best_classifier_refit2.fit(
    train_data,
    eval_set=eval_data,
    verbose=1000,
    use_best_model=True,
    plot=False
)

refit_score2 = best_classifier_refit2.best_score_['validation'].get('RMSE')
print(f"\n Model best_classifier_refit2 RMSE score ---------> {refit_score2:.5f}")
# Out:
# 0:	learn: 17.3283819	test: 17.2870729	best: 17.2870729 (0)	total: 5.83ms	remaining: 17.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 11.35135255
# bestIteration = 193
#
# Shrink model to first 194 iterations.
#
#  Model best_classifier_refit2 RMSE score ---------> 11.35135

# %%
best_classifier_refit.save_model('models/catboost_rs1f.cbm')
best_classifier_refit2.save_model('models/catboost_rs2f.cbm')

# %% [markdown]
# ## LGBM

# %% [markdown]
# ### goss

# %%
X = train.drop(drop_cols, axis=1, errors="ignore")
y = train["target_reg"]

# закодируем категориальные признаки
encoder = LabelEncoder()
for col in cat_features:
    X[col] = encoder.fit_transform(X[col])

lgbm_model = lgbm.LGBMRegressor(random_state=random_state,
                               objective="rmse",
                               metric="rmse",
                               boosting_type="goss",
                               n_jobs=-1,
                               )

param_grid = {'learning_rate': [0.25, 0.05],
              'reg_lambda': [0, 0.5, 1],
              'num_leaves': [5, 10],
              'max_bin': [50, 100],
              'boosting_type': ['goss']
              }

perform_grid_search(X, y, lgbm_model, param_grid, rmse_scorer, kf)
# Out:
# Searching for the best parameters...
# Time taken for grid search: 0.29 minutes
# Best parameters:    {'boosting_type': 'goss', 'learning_rate': 0.05, 'max_bin': 50, 'num_leaves': 10, 'reg_lambda': 0}
# Best RMSE score:  12.06
#
# Searching for the best parameters...
# Time taken for grid search: 0.11 minutes
# Best parameters:    {'boosting_type': 'goss', 'learning_rate': 0.05, 'max_bin': 50, 'num_leaves': 5, 'reg_lambda': 0.5}
# Best RMSE score:  11.85
#
# Searching for the best parameters...
# Time taken for grid search: 0.07 minutes
# Best parameters:    {'boosting_type': 'goss', 'learning_rate': 0.05, 'max_bin': 50, 'num_leaves': 10, 'reg_lambda': 0.5}
# Best RMSE score:  12.01

# %%
lgbm_goss_models = []
goss_scores = []
for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    lgb_model = lgbm.LGBMRegressor(objective="rmse",
                                  learning_rate=0.05,
                                  random_state=random_state,
                                  cat_feature=[0, 1, 2],
                                  boosting_type="goss",
                                  max_bin=50,
                                  num_leaves=10,
                                  reg_lambda=0.5,
                                  n_jobs=-1,
                                  )

    lgb_model.fit(X_train,
                  y_train,
                  eval_set=[(X_test, y_test)],
                  eval_metric='rmse',
                  early_stopping_rounds=50,
                  verbose=1000,)
    lgbm_goss_models.append(lgb_model)
    goss_scores.append(np.mean([v for k, v in lgb_model.best_score_["valid_0"].items()
                                 if "rmse" in k], dtype="float16"))

min_rmse_goss = min(goss_scores)
min_index_goss = goss_scores.index(min_rmse_goss)

for i in range(len(goss_scores)):
    print(f"Model lgbm_goss_models {i} RMSE score ---------> {goss_scores[i]:.5f}")
# Out:
# Model lgbm_goss_models 0 RMSE score ---------> 11.55469
# Model lgbm_goss_models 1 RMSE score ---------> 12.25781
# Model lgbm_goss_models 2 RMSE score ---------> 11.57031

# %%
X_train_encoded_goss = X_train_folds[min_index_goss].copy()
X_test_encoded_goss = X_test_folds[min_index_goss].copy()

for col in cat_features:
    X_train_encoded_goss[col] = encoder.fit_transform(X_train_encoded_goss[col])
    X_test_encoded_goss[col] = encoder.fit_transform(X_test_encoded_goss[col])

explainer = shap.TreeExplainer(lgbm_goss_models[min_index_goss])
shap_values = explainer.shap_values(X_train_encoded_goss)
shap.summary_plot(shap_values, X_train_encoded_goss, max_display=25)

# %%
lgbm.plot_importance(lgbm_goss_models[min_index_goss], figsize=(8, 6))
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# максимальная скорость и средний рейтинг самые важные признаки. Неважные признаки: 'deviation_normal_count', 'car_type', 'year_to_start', 'year_to_work'

# %%
cols_to_drop_goss = ['deviation_normal_count', 'car_type', 'year_to_start', 'year_to_work']

lgbm_goss_optimized = lgbm.LGBMRegressor(objective="rmse",
                                        learning_rate=0.05,
                                        random_state=random_state,
                                        cat_feature=[0, 1],
                                        boosting_type="goss",
                                        max_bin=50,
                                        num_leaves=10,
                                        reg_lambda=0.5,
                                        n_jobs=-1,
                                        )

lgbm_goss_optimized.fit(X_train_encoded_goss.drop(cols_to_drop_goss, axis=1),
y_train_folds[min_index_goss],
eval_set=[(X_test_encoded_goss.drop(cols_to_drop_goss, axis=1),
y_test_folds[min_index_goss])],
eval_metric='rmse',
early_stopping_rounds=50,
verbose=1000,)

optimized_goss_score = lgbm_goss_optimized.best_score_['valid_0'].get('rmse')
print(f"\n Model lgbm_goss_optimized RMSE score ---------> {optimized_goss_score:.5f}")
# Out:
#  Model lgbm_goss_optimized RMSE score ---------> 11.60145

# %% [markdown]
# ### dart

# %% [markdown]
# подбор гиперпараметров для LGBMRegressor с использованием метода Dart.

# %%
X = train.drop(drop_cols, axis=1, errors="ignore")
y = train["target_reg"]

le = LabelEncoder()
for col in cat_features:
    X[col] = le.fit_transform(X[col])

param_grid = {'learning_rate': [0.25, 0.05],
              'reg_lambda': [0, 0.5, 1],
              'num_leaves': [5, 10],
              'max_bin': [50, 200, 400],
              'boosting_type': ['dart']
             }

model = lgbm.LGBMRegressor(random_state=random_state,
                          objective="rmse",
                          metric="rmse"
                          )

perform_grid_search(X, y, model, param_grid, rmse_scorer, kf)
# Out:
# Searching for the best parameters...
# Time taken for grid search: 0.32 minutes
# Best parameters:    {'boosting_type': 'dart', 'learning_rate': 0.25, 'max_bin': 200, 'num_leaves': 5, 'reg_lambda': 0}
# Best RMSE score:  11.73
#
# Searching for the best parameters...
# Time taken for grid search: 0.3 minutes
# Best parameters:    {'boosting_type': 'dart', 'learning_rate': 0.25, 'max_bin': 200, 'num_leaves': 10, 'reg_lambda': 0}
# Best RMSE score:  11.53
#
# Searching for the best parameters...
# Time taken for grid search: 0.26 minutes
# Best parameters:    {'boosting_type': 'dart', 'learning_rate': 0.25, 'max_bin': 50, 'num_leaves': 5, 'reg_lambda': 0}
# Best RMSE score:  11.62

# %% [markdown]
# обучает модели LGBMRegressor с Dart на разных фолдах и сохраняет их в список lgb_dart_models.

# %%
lgb_dart_models = []
dart_scores = []
for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    lgb_model = lgbm.LGBMRegressor(objective="rmse",
                                  learning_rate=0.25,
                                  random_state=random_state,
                                  cat_feature=[0, 1, 2],
                                  boosting_type="dart",
                                  max_bin=400,
                                  num_leaves=10,
                                  reg_lambda=1,
                                  n_jobs=-1,
                                 )
    lgb_model.fit(X_train,
                  y_train,
                  eval_set=[(X_test, y_test)],
                  eval_metric='rmse',
                  early_stopping_rounds=50,
                  verbose=1000,)
    lgb_dart_models.append(lgb_model)
    dart_scores.append(np.mean([v for k, v in lgb_model.best_score_["valid_0"].items()
                                if "rmse" in k], dtype="float16"))
min_rmse_dart = min(dart_scores)
min_index_dart = dart_scores.index(min_rmse_dart)
assert len(lgb_dart_models) == n_splits
for i in range(len(dart_scores)):
    print(f"Model lgb_models_dart {i} RMSE score ---------> {dart_scores[i]:.5f}")
# Out:
# Model lgb_models_dart 0 RMSE score ---------> 11.35938
# Model lgb_models_dart 1 RMSE score ---------> 12.11719
# Model lgb_models_dart 2 RMSE score ---------> 11.53125

# %% [markdown]
# вычисляет значения SHAP для модели с наименьшим RMSE.

# %%
X_train_encoded_dart = X_train_folds[min_index_dart].copy()
X_test_encoded_dart = X_test_folds[min_index_dart].copy()
for col in cat_features:
    X_train_encoded_dart[col] = le.fit_transform(X_train_encoded_dart[col])
    X_test_encoded_dart[col] = le.fit_transform(X_test_encoded_dart[col])

explainer = shap.TreeExplainer(lgb_dart_models[min_index_dart])
shap_values = explainer.shap_values(X_train_encoded_dart)
shap.summary_plot(shap_values, X_train_encoded_dart, max_display=25)

# %% [markdown]
# строит график важности признаков для модели с наименьшим RMSE.

# %%
lgbm.plot_importance(lgb_dart_models[min_index_dart], figsize=(8, 6));

# %% [markdown]
# максимальная скорость и средний рейтинг самые важные признаки, неважные признаки: 'deviation_normal_count', 'year_to_start', 'year_to_work'

# %% [markdown]
# удаляет выбранные столбцы из обучающих и тестовых наборов данных и обучает оптимизированную модель на них.

# %%
cols_to_drop_dart = ['deviation_normal_count', 'year_to_start', 'year_to_work']

lgbm_dart_optimized = lgbm.LGBMRegressor(objective="rmse",
                                        learning_rate=0.25,
                                        random_state=random_state,
                                        cat_feature=[0, 1, 2],
                                        boosting_type="dart",
                                        max_bin=400,
                                        num_leaves=10,
                                        reg_lambda=1,
                                        n_jobs=-1,
)
lgbm_dart_optimized.fit(X_train_encoded_dart.drop(cols_to_drop_dart, axis=1),
y_train_folds[min_index_dart],
eval_set=[(X_test_encoded_dart.drop(cols_to_drop_dart, axis=1),
y_test_folds[min_index_dart])],
eval_metric='rmse',
early_stopping_rounds=50,
verbose=1000,)

score_lgb_dart_optimized = lgbm_dart_optimized.best_score_['valid_0'].get('rmse')
print(f"\n Model lgb_dart_optimized RMSE score ---------> {score_lgb_dart_optimized:.5f}")
# Out:
#  Model lgb_dart_optimized RMSE score ---------> 11.50843

# %% [markdown]
# сохраняет оптимизированные модели GOSS и Dart в файлах.

# %%
booster_lgb_goss_optimized, booster_lgb_dart_optimized = lgbm_goss_optimized.booster_, lgbm_dart_optimized.booster_
booster_lgb_goss_optimized.save_model('models/lgb_goss_optimized.cbm')
booster_lgb_dart_optimized.save_model('models/lgb_dart_optimized.cbm')

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ### dart

# %%
X = train.drop(drop_cols, axis=1, errors="ignore")
y = train["target_reg"]
for col in cat_features:
    X[col] = X[col].astype('category')

model = xgb.XGBRegressor(random_state=random_state,
                         objective='reg:squarederror',
                         tree_method="hist",
                         enable_categorical=True,
                         n_jobs=-1,
                         )

param_grid = {'max_depth': [3, 5],
              'max_leaves': [7, 9],
              'min_child_weight': [12, 14],
              'rate_drop': [0.05, 0.1],
              'one_drop': [1],
              'booster': ['dart']
              }

perform_grid_search(X, y, model, param_grid, rmse_scorer, kf)
# Out:
# Searching for the best parameters...
# Time taken for grid search: 6.65 minutes
# Best parameters:    {'booster': 'dart', 'max_depth': 3, 'max_leaves': 9, 'min_child_weight': 12, 'one_drop': 1, 'rate_drop': 0.1}
# Best RMSE score:  11.77
#
# Searching for the best parameters...
# Time taken for grid search: 6.47 minutes
# Best parameters:    {'booster': 'dart', 'max_depth': 3, 'max_leaves': 7, 'min_child_weight': 12, 'one_drop': 1, 'rate_drop': 0.1}
# Best RMSE score:  11.53
#
# Searching for the best parameters...
# Time taken for grid search: 6.12 minutes
# Best parameters:    {'booster': 'dart', 'max_depth': 3, 'max_leaves': 9, 'min_child_weight': 14, 'one_drop': 1, 'rate_drop': 0.05}
# Best RMSE score:  11.68

# %%
xgb_dart_models = []
scores_xgb_dart = []
num_boost_round_ = 1000

learning_rates = np.linspace(0.5, 0.001, num_boost_round_).tolist()
scheduler = xgb.callback.LearningRateScheduler(learning_rates)

params_dart = {'objective': 'reg:squarederror',
               'tree_method': 'hist',
               'seed': random_state,
               'booster': 'dart',
               'max_depth': '5',
               'max_leaves': '9',
               'min_child_weight': '14',
               'one_drop': '1',
               'rate_drop': '0.1',
               'n_jobs': '-1',
               }
for train_index, test_index in kf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    dtrain = xgb.DMatrix(X_train, label=y_train, nthread=-1, enable_categorical=True)
    dtest = xgb.DMatrix(X_test, y_test, nthread=-1, enable_categorical=True)

    booster = xgb.train(params_dart,
                        dtrain=dtrain,
                        num_boost_round=num_boost_round_,
                        evals=[(dtrain, 'dtrain'), (dtest, 'dtest')],
                        verbose_eval=1000,
                        callbacks=[scheduler],
                        early_stopping_rounds=100,
                        )

    xgb_dart_models.append(booster)
    scores_xgb_dart.append(np.mean(booster.best_score))
min_rmse_xgb_dart = min(scores_xgb_dart)
min_index_xgb_dart = scores_xgb_dart.index(min_rmse_xgb_dart)
assert len(xgb_dart_models) == n_splits
for i in range(len(scores_xgb_dart)):
    print(f"Model xgb_dart {i} RMSE score ---------> {scores_xgb_dart[i]:.5f}")
# Out:
# [0]	dtrain-rmse:34.85301	dtest-rmse:34.19596
# [300]	dtrain-rmse:10.06276	dtest-rmse:11.50691
# [0]	dtrain-rmse:34.37833	dtest-rmse:35.62337
# [123]	dtrain-rmse:9.69586	dtest-rmse:12.00597
# [0]	dtrain-rmse:34.81155	dtest-rmse:34.51076
# [410]	dtrain-rmse:10.01182	dtest-rmse:11.42159
# Model xgb_dart 0 RMSE score ---------> 11.49348
# Model xgb_dart 1 RMSE score ---------> 11.98323
# Model xgb_dart 2 RMSE score ---------> 11.41523

# %%
xgb.plot_importance(xgb_dart_models[min_index_xgb_dart], title='Feature Importance Weight');

# %% [markdown]
# максимальная скорость и средний рейтинг самые важные признаки. Неважные признаки: 'deviation_normal_count', 'year_to_start', 'year_to_work', 'car_type', 'fuel_type'

# %%
colsdrop_xgb_dartf = ['deviation_normal_count', 'year_to_start', 'year_to_work', 'car_type', 'fuel_type']

dtrain = xgb.DMatrix(X_train_folds[min_index_xgb_dart].drop(colsdrop_xgb_dartf, axis=1),
                     label=y_train_folds[min_index_xgb_dart],
                     nthread=-1, enable_categorical=True)
dtest = xgb.DMatrix(X_test_folds[min_index_xgb_dart].drop(colsdrop_xgb_dartf, axis=1),
y_test_folds[min_index_xgb_dart],
nthread=-1, enable_categorical=True)

boosterf = xgb.train(params_dart,
dtrain=dtrain,
num_boost_round=num_boost_round_,
evals=[(dtrain, 'dtrain'), (dtest, 'dtest')],
verbose_eval=1000,
callbacks=[scheduler],
early_stopping_rounds=100,
)
xgb_dartf = boosterf
score_xgb_dartf = xgb_dartf.best_score
print(f"\n Model xgb_dartf RMSE score ---------> {score_xgb_dartf:.5f}")
# Out:
# [0]	dtrain-rmse:34.81155	dtest-rmse:34.51076
# [999]	dtrain-rmse:10.05842	dtest-rmse:11.49513
#
#  Model xgb_dartf RMSE score ---------> 11.49513

# %% [markdown]
# ### gbtree

# %% [markdown]
# выполняет подбор гиперпараметров для XGBRegressor с использованием метода gbtree.

# %%
X = train.drop(drop_cols, axis=1, errors="ignore")
y = train["target_reg"]
for col in cat_features:
    X[col] = X[col].astype('category')

model = xgb.XGBRegressor(random_state=random_state,
                         objective= 'reg:squarederror',
                         tree_method="hist",
                         enable_categorical=True,
                         n_jobs=-1,
                          )

param_grid = {'max_depth': [2, 3],
              'max_leaves': [2, 5, 7],
              'colsample_bytree': [0.6, 0.8],
              'min_child_weight': [14, 16],
              'booster': ['gbtree'],
             }

perform_grid_search(X, y, model, param_grid, rmse_scorer, kf)
# Out:
# Searching for the best parameters...
# Time taken for grid search: 0.23 minutes
# Best parameters:    {'booster': 'gbtree', 'colsample_bytree': 0.6, 'max_depth': 2, 'max_leaves': 5, 'min_child_weight': 14}
# Best RMSE score:  12.07
#
# Searching for the best parameters...
# Time taken for grid search: 0.14 minutes
# Best parameters:    {'booster': 'gbtree', 'colsample_bytree': 0.8, 'max_depth': 2, 'max_leaves': 5, 'min_child_weight': 16}
# Best RMSE score:  11.77
#
# Searching for the best parameters...
# Time taken for grid search: 0.12 minutes
# Best parameters:    {'booster': 'gbtree', 'colsample_bytree': 0.6, 'max_depth': 2, 'max_leaves': 5, 'min_child_weight': 14}
# Best RMSE score:  12.13

# %% [markdown]
# обучает модели XGBRegressor с gbtree на разных фолдах и сохраняет их в список xgb_gbtree_models.

# %%
xgb_gbtree_models = []
scores_xgb_gbtree = []

learning_rates = np.linspace(0.5, 0.0001, num_boost_round_).tolist()
scheduler = xgb.callback.LearningRateScheduler(learning_rates)

params_gbtree = {'objective': 'reg:squarederror',
                 'tree_method': 'hist',
                 'seed': random_state,
                 'booster': 'gbtree',
                 'colsample_bytree': '0.6',
                 'max_depth': '2',
                 'min_child_weight': '16',
                 'max_leaves': '5',
                 'n_jobs': '-1',
                 }

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    dtrain = xgb.DMatrix(X_train, label=y_train, nthread=-1, enable_categorical=True)
    dtest = xgb.DMatrix(X_test, y_test, nthread=-1, enable_categorical=True)

    booster = xgb.train(params_gbtree,
                        dtrain=dtrain,
                        num_boost_round=num_boost_round_,
                        evals=[(dtrain, 'dtrain'), (dtest, 'dtest')],
                        verbose_eval=1000,
                        callbacks=[scheduler],
                        early_stopping_rounds=100
                      )
    xgb_gbtree_models.append(booster)
    scores_xgb_gbtree.append(np.mean(booster.best_score))
min_rmse_xgb_gbtree = min(scores_xgb_gbtree)
min_index_xgb_gbtree = scores_xgb_gbtree.index(min_rmse_xgb_gbtree)
assert len(xgb_gbtree_models) == n_splits
for i in range(len(scores_xgb_gbtree)):
    print(f"Model xgb_gbtree {i} RMSE score ---------> {scores_xgb_gbtree[i]:.5f}")
# Out:
# [0]	dtrain-rmse:35.28106	dtest-rmse:34.58397
# [136]	dtrain-rmse:9.01868	dtest-rmse:12.25913
# [0]	dtrain-rmse:34.84167	dtest-rmse:35.99162
# [128]	dtrain-rmse:8.67743	dtest-rmse:12.74686
# [0]	dtrain-rmse:35.28800	dtest-rmse:34.84176
# [110]	dtrain-rmse:9.07610	dtest-rmse:12.03563
# Model xgb_gbtree 0 RMSE score ---------> 11.84010
# Model xgb_gbtree 1 RMSE score ---------> 12.26156
# Model xgb_gbtree 2 RMSE score ---------> 11.73953

# %% [markdown]
# строит график важности признаков для модели с наименьшим RMSE.

# %%
xgb.plot_importance(xgb_gbtree_models[min_index_xgb_gbtree], title='Feature Importance Weight');

# %% [markdown]
# Неважные признаки: 'deviation_normal_count', 'year_to_start', 'year_to_work', 'car_type', 'fuel_type'

# %% [markdown]
# удаляет выбранные столбцы из обучающих и тестовых наборов данных и обучает оптимизированную модель на них.

# %%
colsdrop_xgb_gbtreef = ['deviation_normal_count', 'year_to_start', 'year_to_work', 'car_type', 'fuel_type']

dtrain = xgb.DMatrix(X_train_folds[min_index_xgb_gbtree].drop(colsdrop_xgb_gbtreef, axis=1),
                     label=y_train_folds[min_index_xgb_gbtree],
                     nthread=-1, enable_categorical=True)
dtest = xgb.DMatrix(X_test_folds[min_index_xgb_gbtree].drop(colsdrop_xgb_gbtreef, axis=1),
                    y_test_folds[min_index_xgb_gbtree],
                    nthread=-1, enable_categorical=True)

boosterf = xgb.train(params_gbtree,
                     dtrain=dtrain,
                     num_boost_round=num_boost_round_,
                     evals=[(dtrain, 'dtrain'), (dtest, 'dtest')],
                     verbose_eval=1000,
                     callbacks=[scheduler],
                     early_stopping_rounds=100,
                     )
xgb_gbtreef = boosterf
score_xgb_gbtreef = xgb_gbtreef.best_score
print(f"\n Model xgb_gbtreef RMSE score ---------> {score_xgb_gbtreef:.5f}")
# Out:
# [0]	dtrain-rmse:35.28800	dtest-rmse:34.84176
# [118]	dtrain-rmse:9.06414	dtest-rmse:12.44243
#
#  Model xgb_gbtreef RMSE score ---------> 11.86373

# %% [markdown]
# сохраняет оптимизированные модели Dart и gbtree в файлах.

# %%
xgb_dartf.save_model('models/xgb_dartf.json')
xgb_gbtreef.save_model('models/xgb_gbtreef.json')

# %% [markdown]
# ## Best models

# %%
print(f'Best models:\n')

print(f'clfs_rs1    MIN index {min_index_cb_rs} --- {min_rmse_cb_rs:.5f}')
print(f'clfs_rs1f   MIN index {0} --- {refit_score:.5f}')
print(f'clfs_rs2    MIN index {min_index_cb_rs2} --- {min_rmse_cb_rs2:.5f}')
print(f'clfs_rs2f   MIN index {0} --- {refit_score2:.5f}\n')

print(f'lgb_goss    MIN index {min_index_goss} --- {min_rmse_goss:.5f}')
print(f'lgb_gossf   MIN index {0} --- {optimized_goss_score:.5f}')
print(f'lgb_dart    MIN index {min_index_dart} --- {min_rmse_dart:.5f}')
print(f'lgb_dartf   MIN index {0} --- {score_lgb_dart_optimized:.5f}\n')

print(f'xgb_dart    MIN index {min_index_xgb_dart} --- {min_rmse_xgb_dart:.5f}')
print(f'xgb_dartf   MIN index {0} --- {score_xgb_dartf:.5f}')
print(f'xgb_gbtree  MIN index {min_index_xgb_gbtree} --- {min_rmse_xgb_gbtree:.5f}')
print(f'xgb_gbtreef MIN index {0} --- {score_xgb_gbtreef:.5f}\n')
# Out:
# Best models:
#
# clfs_rs1    MIN index 2 --- 11.36719
# clfs_rs1f   MIN index 0 --- 11.36404
# clfs_rs2    MIN index 2 --- 11.32031
# clfs_rs2f   MIN index 0 --- 11.35135
#
# lgb_goss    MIN index 0 --- 11.55469
# lgb_gossf   MIN index 0 --- 11.60145
# lgb_dart    MIN index 0 --- 11.35938
# lgb_dartf   MIN index 0 --- 11.50843
#
# xgb_dart    MIN index 2 --- 11.41523
# xgb_dartf   MIN index 0 --- 11.49513
# xgb_gbtree  MIN index 2 --- 11.73953
# xgb_gbtreef MIN index 0 --- 11.86373

# %% [markdown]
# В итоге мы получили лучшие модели, обученные на 3 фолдах:
#
# - **CatBoostRegressor** с `random_state` = 830424 и = 12346, наилучший результат на 3 фолде (индекс 2)
# - **LGBMRegressor** с `boosting_type` goss и dart, наилучший результат также на 3 фолде
# - **XGBRegressor** с `boosting_type` dart и gbtree, лучший результат также на 3 фолде
#
# Самый высокий показатель на обучающих данных был у CatBoostRegressor, затем у LGBMRegressor, а самый низкий показатель у XGBRegressor. Однако, модель LGBMRegressor обучается быстрее всех.
#
# Для лучших моделей из набора данных для обучения мы удалили несколько менее важных признаков, что позволило немного улучшить показатель. Получили модели с буквой `f` в конце названия, и именно их мы будем использовать для предсказания.
#
# Затем мы получим прогнозы от 6 лучших моделей, усредним их и сохраним в файл.

# %%
test = pd.read_csv("https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/quickstart_test.csv")
test_drop = test.drop(["car_id", "target_class"], axis=1)

test_lgbm = test_drop.copy()
for col in cat_features:
    test_lgbm[col] = le.fit_transform(test_lgbm[col])

test_xgb = test_drop.copy()
for col in cat_features:
    test_xgb[col] = test_xgb[col].astype('category')

test_xgb_dartf = xgb.DMatrix(test_xgb.drop(colsdrop_xgb_dartf, axis=1),
                              nthread=-1,
                              enable_categorical=True)
test_xgb_gbtreef = xgb.DMatrix(test_xgb.drop(colsdrop_xgb_gbtreef, axis=1),
                               nthread=-1,
                               enable_categorical=True)

# %%
test['target_reg_cb_1'] = best_classifier_refit.predict(test_drop.drop(drop_columns_cb_rs, axis=1))
test['target_reg_cb_2'] = best_classifier_refit2.predict(test_drop.drop(drop_columns_cb_rs2, axis=1))
test['target_reg_lgbm_1'] = lgbm_goss_optimized.predict(test_lgbm.drop(cols_to_drop_goss, axis=1))
test['target_reg_lgbm_2'] = lgbm_dart_optimized.predict(test_lgbm.drop(cols_to_drop_dart, axis=1))
test['target_reg_xgb_1'] = xgb_dartf.predict(test_xgb_dartf, iteration_range=(0, xgb_dartf.best_iteration+1))
test['target_reg_xgb_2'] = xgb_gbtreef.predict(test_xgb_gbtreef)

test['target_reg_mean'] = test[['target_reg_cb_1', 'target_reg_cb_2',
                                'target_reg_lgbm_1', 'target_reg_lgbm_2',
                                'target_reg_xgb_1', 'target_reg_xgb_2'
                               ]].mean(axis=1)

# %%
test['target_reg'] = test['target_reg_mean']
test[['car_id', 'target_reg']].to_csv('simple_baseline_RMSE.csv', index=False)
print('CSV file saved!')
# Out:
# CSV file saved!
